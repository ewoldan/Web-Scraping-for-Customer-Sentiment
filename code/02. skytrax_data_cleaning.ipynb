# %%
import pandas as pd
import numpy as np
import re
import datetime as dt

# %% [markdown]
# Data Cleaning Checklist:
# - Remove Duplicates – Check for and drop duplicate rows.
# - Handle Missing Values – Identify NaN values and decide whether to fill them or drop the rows/columns.
# - Standardize Formats – Ensure dates, numbers, and strings are in a consistent format.
# - Trim Whitespaces – Clean up extra spaces in text fields.
# - Correct Data Types – Convert columns to their appropriate types (e.g., strings to dates, floats to integers).
# - Remove Special Characters – Especially in text or numerical fields that should be clean.
# - Check for Outliers – Identify extreme values that might be errors.
# - Normalize/Categorize Data – Standardize categorical values (e.g., "NY" vs. "New York").
# - Validate Data – Ensure values fall within expected ranges.
# - Check for Duplicated or Incorrect Entries in Key Columns – Especially if you have primary keys or important identifiers.

# %% [markdown]
# - do both dates columns
# - check verification_status, why for some lines it is broken?
# - do from and to destination
# - 1: "Very Poor", 2: "Poor", 3: "Neutral", 4: "Good", 5: "Excellent" with mapping

# %%
df = pd.read_csv('skytrax-data.csv')
df.head()
# Out:
#     date_published                                        review_text  \
# 0  19th March 2025  ✅Trip Verified|   Flight mainly let down by a ...
# 1  16th March 2025  ✅Trip Verified|   Another awful experience by ...
# 2  16th March 2025  ✅Trip Verified|   The service was rude, full o...
# 3  16th March 2025  ✅Trip Verified|   This flight was a joke. Ther...
# 4   7th March 2025  ✅Trip Verified|   This time British Airways ma...
#
#        aircraft type_of_traveller        seat_type                route  \
# 0    Boeing 787      Solo Leisure   Business Class  Cape Town to London
# 1  Not informed          Business   Business Class     London to Geneva
# 2  Not informed          Business  Premium Economy   London to New York
# 3  Not informed          Business   Business Class   Chambery to London
# 4    Boeing 777          Business  Premium Economy   Gatwick to Antigua
#
#       date_flown  seat_comfort_ranking  cabin_staff_service_ranking  \
# 0     March 2025                   5.0                          2.0
# 1  December 2024                   1.0                          1.0
# 2   January 2025                   1.0                          1.0
# 3   January 2025                   1.0                          1.0
# 4     March 2025                   5.0                          5.0
#
#    food_beverages_ranking  ground_services_ranking  value_for_money  \
# 0                     5.0                      4.0                4
# 1                     NaN                      1.0                1
# 2                     1.0                      5.0                1
# 3                     2.0                      1.0                1
# 4                     4.0                      5.0                5
#
#   recommended
# 0         yes
# 1          no
# 2          no
# 3          no
# 4         yes

# %%
df.dtypes
# Out:
# date_published                  object
# review_text                     object
# aircraft                        object
# type_of_traveller               object
# seat_type                       object
# route                           object
# date_flown                      object
# seat_comfort_ranking           float64
# cabin_staff_service_ranking    float64
# food_beverages_ranking         float64
# ground_services_ranking        float64
# value_for_money                  int64
# recommended                     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# date_published                   0
# review_text                      0
# aircraft                         0
# type_of_traveller                0
# seat_type                        0
# route                            0
# date_flown                     774
# seat_comfort_ranking           126
# cabin_staff_service_ranking    141
# food_beverages_ranking         438
# ground_services_ranking        846
# value_for_money                  0
# recommended                      0
# dtype: int64

# %%
df.loc[df["review_text"].str.startswith(("✅", "❎"), na=False), "review_text"] = df["review_text"].str[1:]

# %%
df[["verification_status", "review_text_clean"]] = df["review_text"].str.split(r'\|\s+', n=1, expand=True)

# %%
df.loc[df["review_text_clean"].isna(), "review_text_clean"] = df["verification_status"]
df.loc[df["verification_status"] == df["review_text_clean"], "verification_status"] = "Not informed"

# %%
conditions = [
    df['verification_status'].str.contains('Not Verified', case=False, na=False),
    df['verification_status'].str.contains('Trip Verified', case=False, na=False),
]

choices = ['Not Verified', 'Trip Verified']


df['verification_status'] = np.select(conditions, choices, default='Not informed')

# %%
df = df.drop(columns = 'review_text')
df.head()
# Out:
#     date_published      aircraft type_of_traveller        seat_type  \
# 0  19th March 2025    Boeing 787      Solo Leisure   Business Class
# 1  16th March 2025  Not informed          Business   Business Class
# 2  16th March 2025  Not informed          Business  Premium Economy
# 3  16th March 2025  Not informed          Business   Business Class
# 4   7th March 2025    Boeing 777          Business  Premium Economy
#
#                  route     date_flown  seat_comfort_ranking  \
# 0  Cape Town to London     March 2025                   5.0
# 1     London to Geneva  December 2024                   1.0
# 2   London to New York   January 2025                   1.0
# 3   Chambery to London   January 2025                   1.0
# 4   Gatwick to Antigua     March 2025                   5.0
#
#    cabin_staff_service_ranking  food_beverages_ranking  \
# 0                          2.0                     5.0
# 1                          1.0                     NaN
# 2                          1.0                     1.0
# 3                          1.0                     2.0
# 4                          5.0                     4.0
#
#    ground_services_ranking  value_for_money recommended verification_status  \
# 0                      4.0                4         yes       Trip Verified
# 1                      1.0                1          no       Trip Verified
# 2                      5.0                1          no       Trip Verified
# 3                      1.0                1          no       Trip Verified
# 4                      5.0                5         yes       Trip Verified
#
#                                    review_text_clean
# 0  Flight mainly let down by a disagreeable fligh...
# 1  Another awful experience by British Airways. T...
# 2  The service was rude, full of attitude to me, ...
# 3  This flight was a joke. There was four people ...
# 4  This time British Airways managed to get every...

# %%
df['date_published'] = df['date_published'].str.replace(r'(\d+)(st|nd|rd|th)', r'\1', regex=True)
df['date_published'] = pd.to_datetime(df['date_published'], format="%d %B %Y", errors='coerce')
df.head()
# Out:
#   date_published      aircraft type_of_traveller        seat_type  \
# 0     2025-03-19    Boeing 787      Solo Leisure   Business Class
# 1     2025-03-16  Not informed          Business   Business Class
# 2     2025-03-16  Not informed          Business  Premium Economy
# 3     2025-03-16  Not informed          Business   Business Class
# 4     2025-03-07    Boeing 777          Business  Premium Economy
#
#                  route     date_flown  seat_comfort_ranking  \
# 0  Cape Town to London     March 2025                   5.0
# 1     London to Geneva  December 2024                   1.0
# 2   London to New York   January 2025                   1.0
# 3   Chambery to London   January 2025                   1.0
# 4   Gatwick to Antigua     March 2025                   5.0
#
#    cabin_staff_service_ranking  food_beverages_ranking  \
# 0                          2.0                     5.0
# 1                          1.0                     NaN
# 2                          1.0                     1.0
# 3                          1.0                     2.0
# 4                          5.0                     4.0
#
#    ground_services_ranking  value_for_money recommended verification_status  \
# 0                      4.0                4         yes       Trip Verified
# 1                      1.0                1          no       Trip Verified
# 2                      5.0                1          no       Trip Verified
# 3                      1.0                1          no       Trip Verified
# 4                      5.0                5         yes       Trip Verified
#
#                                    review_text_clean
# 0  Flight mainly let down by a disagreeable fligh...
# 1  Another awful experience by British Airways. T...
# 2  The service was rude, full of attitude to me, ...
# 3  This flight was a joke. There was four people ...
# 4  This time British Airways managed to get every...

# %% [markdown]
# df[['month_flown', 'year_flown']] = df['date_flown'].where(
#     df['date_flown'] != 'Not informed.').str.split(" ", n=2, expand=True)

# %%
df['date_flown'] = pd.to_datetime(df['date_flown'], format='%B %Y', errors='coerce').dt.date

# %% [markdown]
# ## will keep numbers instead to calculate avarage score & with NTILE() in SQL calculate portion to assign ranking
#
# ranking_map = {
#     '1': 'Very Poor',
#     '2': 'Poor',
#     '3': 'Neutral',
#     '4': 'Good',
#     '5': 'Excellent'
# }
#
# df[['seat_comfort_ranking', 'cabin_staff_service_ranking', 'food_beverages_ranking',
#     'ground_services_ranking', 'value_for_money']] = df[['seat_comfort_ranking',
#     'cabin_staff_service_ranking', 'food_beverages_ranking',
#     'ground_services_ranking', 'value_for_money']].astype(str).applymap(ranking_map.get)

# %%
df
# Out:
#      date_published      aircraft type_of_traveller        seat_type  \
# 0        2025-03-19    Boeing 787      Solo Leisure   Business Class
# 1        2025-03-16  Not informed          Business   Business Class
# 2        2025-03-16  Not informed          Business  Premium Economy
# 3        2025-03-16  Not informed          Business   Business Class
# 4        2025-03-07    Boeing 777          Business  Premium Economy
# ...             ...           ...               ...              ...
# 3915     2012-08-29  Not informed      Not informed    Economy Class
# 3916     2012-08-29  Not informed      Not informed   Business Class
# 3917     2012-08-29  Not informed      Not informed  Premium Economy
# 3918     2012-08-29  Not informed      Not informed   Business Class
# 3919     2012-08-29  Not informed      Not informed    Economy Class
#
#                     route  date_flown  seat_comfort_ranking  \
# 0     Cape Town to London  2025-03-01                   5.0
# 1        London to Geneva  2024-12-01                   1.0
# 2      London to New York  2025-01-01                   1.0
# 3      Chambery to London  2025-01-01                   1.0
# 4      Gatwick to Antigua  2025-03-01                   5.0
# ...                   ...         ...                   ...
# 3915         Not informed         NaT                   2.0
# 3916         Not informed         NaT                   4.0
# 3917         Not informed         NaT                   4.0
# 3918         Not informed         NaT                   4.0
# 3919         Not informed         NaT                   5.0
#
#       cabin_staff_service_ranking  food_beverages_ranking  \
# 0                             2.0                     5.0
# 1                             1.0                     NaN
# 2                             1.0                     1.0
# 3                             1.0                     2.0
# 4                             5.0                     4.0
# ...                           ...                     ...
# 3915                          3.0                     1.0
# 3916                          3.0                     3.0
# 3917                          3.0                     3.0
# 3918                          3.0                     2.0
# 3919                          5.0                     5.0
#
#       ground_services_ranking  value_for_money recommended  \
# 0                         4.0                4         yes
# 1                         1.0                1          no
# 2                         5.0                1          no
# 3                         1.0                1          no
# 4                         5.0                5         yes
# ...                       ...              ...         ...
# 3915                      NaN                3          no
# 3916                      NaN                0         yes
# 3917                      NaN                4         yes
# 3918                      NaN                3         yes
# 3919                      NaN                4         yes
#
#      verification_status                                  review_text_clean
# 0          Trip Verified  Flight mainly let down by a disagreeable fligh...
# 1          Trip Verified  Another awful experience by British Airways. T...
# 2          Trip Verified  The service was rude, full of attitude to me, ...
# 3          Trip Verified  This flight was a joke. There was four people ...
# 4          Trip Verified  This time British Airways managed to get every...
# ...                  ...                                                ...
# 3915        Not informed  LHR-JFK-LAX-LHR. Check in was ok apart from be...
# 3916        Not informed  HKG-LHR in New Club World on Boeing 777-300 - ...
# 3917        Not informed  YYZ to LHR - July 2012 - I flew overnight in p...
# 3918        Not informed  Flew return in CW from LHR to BKK in August 20...
# 3919        Not informed  Flew LHR - VIE return operated by bmi but BA a...
#
# [3920 rows x 14 columns]

# %%
df['flight_type'] = np.where(df['route'].str.contains('via', case=False, na=False), 'layover', 'direct')
df
# Out:
#      date_published      aircraft type_of_traveller        seat_type  \
# 0        2025-03-19    Boeing 787      Solo Leisure   Business Class
# 1        2025-03-16  Not informed          Business   Business Class
# 2        2025-03-16  Not informed          Business  Premium Economy
# 3        2025-03-16  Not informed          Business   Business Class
# 4        2025-03-07    Boeing 777          Business  Premium Economy
# ...             ...           ...               ...              ...
# 3915     2012-08-29  Not informed      Not informed    Economy Class
# 3916     2012-08-29  Not informed      Not informed   Business Class
# 3917     2012-08-29  Not informed      Not informed  Premium Economy
# 3918     2012-08-29  Not informed      Not informed   Business Class
# 3919     2012-08-29  Not informed      Not informed    Economy Class
#
#                     route  date_flown  seat_comfort_ranking  \
# 0     Cape Town to London  2025-03-01                   5.0
# 1        London to Geneva  2024-12-01                   1.0
# 2      London to New York  2025-01-01                   1.0
# 3      Chambery to London  2025-01-01                   1.0
# 4      Gatwick to Antigua  2025-03-01                   5.0
# ...                   ...         ...                   ...
# 3915         Not informed         NaT                   2.0
# 3916         Not informed         NaT                   4.0
# 3917         Not informed         NaT                   4.0
# 3918         Not informed         NaT                   4.0
# 3919         Not informed         NaT                   5.0
#
#       cabin_staff_service_ranking  food_beverages_ranking  \
# 0                             2.0                     5.0
# 1                             1.0                     NaN
# 2                             1.0                     1.0
# 3                             1.0                     2.0
# 4                             5.0                     4.0
# ...                           ...                     ...
# 3915                          3.0                     1.0
# 3916                          3.0                     3.0
# 3917                          3.0                     3.0
# 3918                          3.0                     2.0
# 3919                          5.0                     5.0
#
#       ground_services_ranking  value_for_money recommended  \
# 0                         4.0                4         yes
# 1                         1.0                1          no
# 2                         5.0                1          no
# 3                         1.0                1          no
# 4                         5.0                5         yes
# ...                       ...              ...         ...
# 3915                      NaN                3          no
# 3916                      NaN                0         yes
# 3917                      NaN                4         yes
# 3918                      NaN                3         yes
# 3919                      NaN                4         yes
#
#      verification_status                                  review_text_clean  \
# 0          Trip Verified  Flight mainly let down by a disagreeable fligh...
# 1          Trip Verified  Another awful experience by British Airways. T...
# 2          Trip Verified  The service was rude, full of attitude to me, ...
# 3          Trip Verified  This flight was a joke. There was four people ...
# 4          Trip Verified  This time British Airways managed to get every...
# ...                  ...                                                ...
# 3915        Not informed  LHR-JFK-LAX-LHR. Check in was ok apart from be...
# 3916        Not informed  HKG-LHR in New Club World on Boeing 777-300 - ...
# 3917        Not informed  YYZ to LHR - July 2012 - I flew overnight in p...
# 3918        Not informed  Flew return in CW from LHR to BKK in August 20...
# 3919        Not informed  Flew LHR - VIE return operated by bmi but BA a...
#
#      flight_type
# 0         direct
# 1         direct
# 2         direct
# 3         direct
# 4         direct
# ...          ...
# 3915      direct
# 3916      direct
# 3917      direct
# 3918      direct
# 3919      direct
#
# [3920 rows x 15 columns]

# %%
df[['departure', 'destination', 'layover']] = df['route'].str.extract(
    r'^(.*?)(?:\s(?:to|–|-)\s(.*?))?(?:\s(?:via|through)\s(.*))?$')

df['destination'] = df['destination'].fillna(df['layover'])
df['layover'] = df['layover'].where(df['layover'] != df['destination'], 'Not Applicable')

df.head()
# Out:
#   date_published      aircraft type_of_traveller        seat_type  \
# 0     2025-03-19    Boeing 787      Solo Leisure   Business Class
# 1     2025-03-16  Not informed          Business   Business Class
# 2     2025-03-16  Not informed          Business  Premium Economy
# 3     2025-03-16  Not informed          Business   Business Class
# 4     2025-03-07    Boeing 777          Business  Premium Economy
#
#                  route  date_flown  seat_comfort_ranking  \
# 0  Cape Town to London  2025-03-01                   5.0
# 1     London to Geneva  2024-12-01                   1.0
# 2   London to New York  2025-01-01                   1.0
# 3   Chambery to London  2025-01-01                   1.0
# 4   Gatwick to Antigua  2025-03-01                   5.0
#
#    cabin_staff_service_ranking  food_beverages_ranking  \
# 0                          2.0                     5.0
# 1                          1.0                     NaN
# 2                          1.0                     1.0
# 3                          1.0                     2.0
# 4                          5.0                     4.0
#
#    ground_services_ranking  value_for_money recommended verification_status  \
# 0                      4.0                4         yes       Trip Verified
# 1                      1.0                1          no       Trip Verified
# 2                      5.0                1          no       Trip Verified
# 3                      1.0                1          no       Trip Verified
# 4                      5.0                5         yes       Trip Verified
#
#                                    review_text_clean flight_type  departure  \
# 0  Flight mainly let down by a disagreeable fligh...      direct  Cape Town
# 1  Another awful experience by British Airways. T...      direct     London
# 2  The service was rude, full of attitude to me, ...      direct     London
# 3  This flight was a joke. There was four people ...      direct   Chambery
# 4  This time British Airways managed to get every...      direct    Gatwick
#
#   destination layover
# 0      London     NaN
# 1      Geneva     NaN
# 2    New York     NaN
# 3      London     NaN
# 4     Antigua     NaN

# %%
df.to_csv('skytrax-data-clean.csv', index=False)
